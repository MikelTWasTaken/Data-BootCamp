# %%
# 🌟Exercise 1: Introduction to Data Analysis (Easy)


# Objective: Understand the basic overview and significance of data analysis.
# Task:
# Write a short essay or report on the following topics:

# What is data analysis? -  data analysis is a process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, informing conclusions, and supporting decision-making.
# Why is data analysis important in modern contexts? - it’s a necessity for informed decision-making and strategic planning.
# List and describe three areas where data analysis is applied today. - Business, Science, Engineering

# %%
# 🌟Exercise 2: Dataset Loading and Initial Analysis

# Objective: Practice dataset loading from Kaggle and initial analysis.
# Task:
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.

# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/teitelbaumsair/Downloads/How Much Sleep Do Americans/Time Americans Spend Sleeping.csv")

# %%
df1 = pd.read_csv("/Users/teitelbaumsair/Downloads/Global Trends in Mental Health Disorder/Mental health Depression disorder Data.csv")
# Out:
# /var/folders/_7/7nx4t_6s6995xg_cj866wrmr0000gn/T/ipykernel_57673/1380346412.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("/Users/teitelbaumsair/Downloads/Global Trends in Mental Health Disorder/Mental health Depression disorder Data.csv")

# %%
df2 = pd.read_csv("/Users/teitelbaumsair/Downloads/Credit Card Approvals (Clean Data)/clean_dataset.csv")

# %%
df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
df.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
df1.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
df1.describe()
# Out:
#                index  Anxiety disorders (%)  Drug use disorders (%)  \
# count  108553.000000            6468.000000             6468.000000
# mean    54276.000000               3.989921                0.862278
# std     31336.696223               1.167526                0.460679
# min         0.000000               2.023393                0.383650
# 25%     27138.000000               3.188824                0.535064
# 50%     54276.000000               3.554373                0.726430
# 75%     81414.000000               4.682163                0.940157
# max    108552.000000               8.967330                3.452476
#
#        Depression (%)  Alcohol use disorders (%)
# count     6468.000000                6468.000000
# mean         3.497654                   1.585821
# std          0.655859                   0.860283
# min          2.139903                   0.446940
# 25%          3.005529                   0.993685
# 50%          3.499606                   1.479936
# ...

# %%
df2.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
df2.describe()
# Out:
#            Gender         Age        Debt     Married  BankCustomer  \
# count  690.000000  690.000000  690.000000  690.000000    690.000000
# mean     0.695652   31.514116    4.758725    0.760870      0.763768
# std      0.460464   11.860245    4.978163    0.426862      0.425074
# min      0.000000   13.750000    0.000000    0.000000      0.000000
# 25%      0.000000   22.670000    1.000000    1.000000      1.000000
# 50%      1.000000   28.460000    2.750000    1.000000      1.000000
# 75%      1.000000   37.707500    7.207500    1.000000      1.000000
# max      1.000000   80.250000   28.000000    1.000000      1.000000
#
#        YearsEmployed  PriorDefault    Employed  CreditScore  DriversLicense  \
# count     690.000000    690.000000  690.000000    690.00000      690.000000
# mean        2.223406      0.523188    0.427536      2.40000        0.457971
# std         3.346513      0.499824    0.495080      4.86294        0.498592
# ...

# %%
# 🌟Exercise 3: Identifying Data Types
# Task:
# For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.
#df - 	QUAL = Period, Type of Days, Age Group,	Activity,Sex
#df -   QUANT =  index,	Year, Avg hrs per day sleeping, Standard Error	
#Explanation - QUAL columns variables represent categories or descriptive labels. QUANT variables involve numeric values that can be measured or counted.

#df1 - 	QUAL = Entity, Code
#df1 -   QUANT =   index, Year,	Schizophrenia (%),	Bipolar disorder (%), Eating disorders (%),	Anxiety disorders (%),	Drug use disorders (%),	Depression (%),	Alcohol use disorders (%)
#Explanation - QUAL columns variables represent categories or descriptive labels. QUANT variables involve numeric values that can be measured or counted.

#df2 - 	QUAL = Age,	Debt, Years Employed, CreditScore, ZipCode, Income
#df2 -   QUANT =   Gender, Married, BankCustomer, Industry,	Ethnicity, PriorDefault	Employed, DriversLicense, Citizen, Approved
#Explanation - QUAL columns variables represent categories or descriptive labels. QUANT variables involve numeric values that can be measured or counted.

# %%
# 🌟Exercise 4: Exploring Data Types
# Objective: Learn about different types of data in data analysis.
# Task:
# Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.
# Tools: Jupyter Notebook, Python with Pandas library.

Iris = pd.read_csv("/Users/teitelbaumsair/Downloads/Iris Dataset/Iris.csv")

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#QUAL Species
#QUANT 	Id	SepalLengthCm	SepalWidthCm	PetalLengthCm	PetalWidthCm
#Explanation - QUAL columns variables represent categories or descriptive labels. QUANT variables involve numeric values that can be measured or counted.

# %%
# 🌟Exercise 5: Basic Data Analysis with Google Colab


# Objective: Perform basic data analysis using Google Colab.
# Task:
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
mean_PetalWidthCm = Iris['PetalWidthCm'].mean()
print(f"Mean PetalWidthCm: {mean_PetalWidthCm}")

median_SepalLengthCm = Iris['SepalLengthCm'].median()
print(f"Median SepalLengthCm: {median_SepalLengthCm}")

mode_SepalWidthCm = Iris['SepalWidthCm'].mode()
print(f"Mode SepalWidthCm: {mode_SepalWidthCm}")

# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries :
import matplotlib.pyplot as plt
data = pd.read_csv('/Users/teitelbaumsair/Downloads/Iris Dataset/Iris.csv')
plt.bar(data['SepalWidthCm'], data['SepalLengthCm'], color='skyblue')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Sepal Length (cm)')
plt.title('Sepal Width vs. Sepal Length')
plt.show()

# Document your findings in the notebook.
#Generally speaking Sepal's with an average width are Longer. slim and wide sepals are generally shorter. 
# Tools: Google Colab, Python with Pandas and Matplotlib/Seaborn libraries.
# Out:
# Mean PetalWidthCm: 1.1986666666666668
# Median SepalLengthCm: 5.8
# Mode SepalWidthCm: 0    3.0
# Name: SepalWidthCm, dtype: float64

# %%
# 🌟Exercise 6: Basic Observation Skills in Data Analysis
# Objective: Develop observation skills for data analysis.
# Task:
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# Tools: Jupyter Notebook, Python with Pandas library.
df = pd.read_csv("/Users/teitelbaumsair/Downloads/How Much Sleep Do Americans/Time Americans Spend Sleeping.csv")
df.head()
#two columns that would be interesting to analyze for trend analysis is avg hours per day sleeping  across the years this study was conducted.
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

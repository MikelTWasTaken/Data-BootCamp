# %%
import os

# Check if the directory exists; if not, create it
path = '/Users/teitelbaumsair/Desktop/DI_Bootcamp'
if not os.path.exists(path):
    os.makedirs(path)

# Change to the new directory
os.chdir(path)
print(os.getcwd())
# Out:
# /Users/teitelbaumsair/Desktop/DI_Bootcamp

# %%
data = pd.read_csv("operations1.csv",parse_dates=[0])
print (data)
# Out:
#     transaction_date                                label  amount  \
# 0         2023-03-31        DONATION XX XX XX XX XX XX XX   -1.44
# 1         2023-04-03                 PAYMENT XX XX MTA XX  -24.00
# 2         2023-04-03                 PAYMENT XX XX MTA XX  -73.00
# 3         2023-04-03                  PAYMENT XX XX XX XX  -14.39
# 4         2023-04-03           TRANSFER XX XX XX XX XX XX    4.80
# ..               ...                                  ...     ...
# 303       2023-10-05                  PAYMENT XX XX XX XX   -4.80
# 304       2023-10-05            PAYMENT XX XX XX XX XX XX  -10.64
# 305       2023-10-06  PRE-AUTH PAYMENT XX TELEPHONE XX XX  -13.58
# 306       2023-10-06            PAYMENT XX XX CHEZ LUC XX  -10.00
# 307       2023-10-06   FEES SUPERBANK ACCOUNT XX XX XX XX   -1.92
#
#      balance_bef_trn           categ      type     expense_slice   debcr  \
# 0            1515.25           OTHER  DONATION             small   debit
# 1            1513.81       TRANSPORT   PAYMENT             small   debit
# 2            1489.81       TRANSPORT   PAYMENT             small   debit
# 3            1416.81           OTHER   PAYMENT             small   debit
# 4            1402.42           OTHER  TRANSFER  (not an expense)  credit
# ..               ...             ...       ...               ...     ...
# 303          2440.94           OTHER   PAYMENT             small   debit
# 304          2436.14           OTHER   PAYMENT             small   debit
# 305          2425.50  TELEPHONE BILL     OTHER             small   debit
# 306          2411.92      RESTAURANT   PAYMENT             small   debit
# 307          2401.92       BANK FEES     OTHER             small   debit
#
#      year  month  day  day_week  day_week_num  weekend  quart_month
# 0    2023      3   31    Friday             5    False            4
# 1    2023      4    3    Monday             1    False            1
# 2    2023      4    3    Monday             1    False            1
# 3    2023      4    3    Monday             1    False            1
# 4    2023      4    3    Monday             1    False            1
# ..    ...    ...  ...       ...           ...      ...          ...
# 303  2023     10    5  Thursday             4    False            1
# 304  2023     10    5  Thursday             4    False            1
# 305  2023     10    6    Friday             5    False            1
# 306  2023     10    6    Friday             5    False            1
# 307  2023     10    6    Friday             5    False            1
#
# [308 rows x 15 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("operations1.csv",parse_dates=[0])

# %%
import matplotlib.pyplot as plt

# QUALITATIVE VARIABLE
# Pie chart
data["categ"].value_counts(normalize=True).plot(kind='pie')
# This line ensures that the pie chart is circular, not elliptical
plt.axis('equal') 
plt.show() # Displays the graph

# Bar graph
data["categ"].value_counts(normalize=True).plot(kind='bar')
plt.show()

# QUANTITATIVE VARIABLE
# Vertical line graph
data["quart_month"].value_counts(normalize=True).plot(kind='bar',width=0.1)
plt.show()

# Histogram
data["amount"].hist(normed=True)
plt.show()
# Prettier Histogram
data[data.amount.abs() < 100]["amount"].hist(density=True,bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 20
#      17 plt.show()
#      19 # Histogram
# ---> 20 data["amount"].hist(normalize=True)
#      21 plt.show()
#      22 # Prettier Histogram
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/plotting/_core.py:129, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      62 """
#      63 Draw histogram of the input series using matplotlib.
#      64
#    (...)
#     126     >>> hist = ser.groupby(level=0).hist()
#     127 """
#     128 plot_backend = _get_plot_backend(backend)
# --> 129 return plot_backend.hist_series(
#     130     self,
#     131     by=by,
#     132     ax=ax,
#     133     grid=grid,
#     134     xlabelsize=xlabelsize,
#     135     xrot=xrot,
#     136     ylabelsize=ylabelsize,
#     137     yrot=yrot,
#     138     figsize=figsize,
#     139     bins=bins,
#     140     legend=legend,
#     141     **kwargs,
#     142 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/plotting/_matplotlib/hist.py:454, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     452 if legend:
#     453     kwds["label"] = self.name
# --> 454 ax.hist(values, bins=bins, **kwds)
#     455 if legend:
#     456     ax.legend()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py:7154, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7152 if patch:
#    7153     p = patch[0]
# -> 7154     p._internal_update(kwargs)
#    7155     if lbl is not None:
#    7156         p.set_label(lbl)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'normalize'

# %%
import os

# Check if the directory exists; if not, create it
path = '/Users/teitelbaumsair/Desktop/DI_Bootcamp'
if not os.path.exists(path):
    os.makedirs(path)

# Change to the new directory
os.chdir(path)
print(os.getcwd())

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("operations1.csv",parse_dates=[0])
occurrences = data["quart_month"].value_counts()
categories = occurrences.index # the occurrences index contains the categories

tab = pd.DataFrame(categories, columns = ["quart_month"]) # creation of table based on categories
tab["n"] = occurrences.values
tab["f"] = tab["n"] / len(data) # len(data) returns the sample size
# Out:
# /Users/teitelbaumsair/Desktop/DI_Bootcamp

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("operations1.csv",parse_dates=[0])
occurrences = data["quart_month"].value_counts()
categories = occurrences.index # the occurrences index contains the categories

tab = pd.DataFrame(categories, columns = ["quart_month"]) # creation of table based on categories
tab["n"] = occurrences.values
tab["f"] = tab["n"] / len(data) # len(data) returns the sample size
print (data)
# Out:
#     transaction_date                                label  amount  \
# 0         2023-03-31        DONATION XX XX XX XX XX XX XX   -1.44
# 1         2023-04-03                 PAYMENT XX XX MTA XX  -24.00
# 2         2023-04-03                 PAYMENT XX XX MTA XX  -73.00
# 3         2023-04-03                  PAYMENT XX XX XX XX  -14.39
# 4         2023-04-03           TRANSFER XX XX XX XX XX XX    4.80
# ..               ...                                  ...     ...
# 303       2023-10-05                  PAYMENT XX XX XX XX   -4.80
# 304       2023-10-05            PAYMENT XX XX XX XX XX XX  -10.64
# 305       2023-10-06  PRE-AUTH PAYMENT XX TELEPHONE XX XX  -13.58
# 306       2023-10-06            PAYMENT XX XX CHEZ LUC XX  -10.00
# 307       2023-10-06   FEES SUPERBANK ACCOUNT XX XX XX XX   -1.92
#
#      balance_bef_trn           categ      type     expense_slice   debcr  \
# 0            1515.25           OTHER  DONATION             small   debit
# 1            1513.81       TRANSPORT   PAYMENT             small   debit
# 2            1489.81       TRANSPORT   PAYMENT             small   debit
# 3            1416.81           OTHER   PAYMENT             small   debit
# 4            1402.42           OTHER  TRANSFER  (not an expense)  credit
# ..               ...             ...       ...               ...     ...
# 303          2440.94           OTHER   PAYMENT             small   debit
# 304          2436.14           OTHER   PAYMENT             small   debit
# 305          2425.50  TELEPHONE BILL     OTHER             small   debit
# 306          2411.92      RESTAURANT   PAYMENT             small   debit
# 307          2401.92       BANK FEES     OTHER             small   debit
#
#      year  month  day  day_week  day_week_num  weekend  quart_month
# 0    2023      3   31    Friday             5    False            4
# 1    2023      4    3    Monday             1    False            1
# 2    2023      4    3    Monday             1    False            1
# 3    2023      4    3    Monday             1    False            1
# 4    2023      4    3    Monday             1    False            1
# ..    ...    ...  ...       ...           ...      ...          ...
# 303  2023     10    5  Thursday             4    False            1
# 304  2023     10    5  Thursday             4    False            1
# 305  2023     10    6    Friday             5    False            1
# 306  2023     10    6    Friday             5    False            1
# 307  2023     10    6    Friday             5    False            1
#
# [308 rows x 15 columns]

# %%
for cat in data["categ"].unique():
    subset = data[data.categ == cat] # Creation of sub-sample
    print("-"*20)
    print(cat)
    print("mean”:\n",subset['amount'].mean())
    print("med:\n",subset['amount'].median())
    print("mod:\n",subset['amount'].mode())
    subset["amount"].hist() # Creates the histogram
    plt.show() # Displays the histogram
# Out:
# --------------------
# OTHER
# mean”:
#  23.43320754716981
# med:
#  -8.31
# mod:
#  0   -1.6
# Name: amount, dtype: float64
# --------------------
# TRANSPORT
# mean”:
#  -52.99714285714286
# med:
#  -53.1
# mod:
#  0   -73.0
# Name: amount, dtype: float64
# --------------------
# TELEPHONE BILL
# mean”:
#  -12.045714285714283
# med:
#  -7.02
# mod:
#  0   -7.02
# 1   -6.38
# Name: amount, dtype: float64
# --------------------
# GROCERIES
# mean”:
#  -16.341282051282054
# med:
#  -12.24
# mod:
#  0    -60.16
# 1    -42.45
# 2    -42.42
# 3    -33.55
# 4    -32.67
# 5    -29.18
# 6    -28.11
# 7    -27.68
# 8    -26.58
# 9    -26.19
# 10   -23.43
# 11   -22.59
# 12   -21.73
# 13   -20.59
# 14   -18.45
# 15   -17.16
# 16   -13.59
# 17   -12.96
# 18   -12.49
# 19   -12.24
# 20   -10.91
# 21   -10.36
# 22    -9.88
# 23    -9.60
# 24    -9.31
# 25    -9.11
# 26    -6.89
# 27    -6.80
# 28    -6.60
# 29    -5.88
# 30    -4.63
# 31    -4.41
# 32    -4.39
# 33    -3.48
# 34    -2.93
# 35    -2.56
# 36    -2.51
# 37    -1.90
# 38    -0.94
# Name: amount, dtype: float64
# --------------------
# BANK FEES
# mean”:
#  -1.8857142857142857
# med:
#  -1.92
# mod:
#  0   -1.92
# Name: amount, dtype: float64
# --------------------
# RESTAURANT
# mean”:
#  -10.3325
# med:
#  -10.1
# mod:
#  0   -9.2
# Name: amount, dtype: float64
# --------------------
# RENT
# mean”:
#  -345.0
# med:
#  -345.0
# mod:
#  0   -345.0
# Name: amount, dtype: float64

# %%
for cat in data["categ"].unique():
    subset = data[data.categ == cat] # Creation of sub-sample
    print("-"*20)
    print(cat)
    print("mean:\n",subset['amount'].mean())
    print("med:\n",subset['amount'].median())
    print("mod:\n",subset['amount'].mode())
    print("var:\n",subset['amount'].var(ddof=0))
    print("ect:\n",subset['amount'].std(ddof=0))
    subset["amount"].hist() # Creates the histogram
    plt.show()  # Displays the histogram
    subset.boxplot(column="amount", vert=False)
    plt.show()
# Out:
# --------------------
# OTHER
# mean:
#  23.43320754716981
# med:
#  -8.31
# mod:
#  0   -1.6
# Name: amount, dtype: float64
# var:
#  40401.82999254183
# ect:
#  201.00206464746034
# --------------------
# TRANSPORT
# mean:
#  -52.99714285714286
# med:
#  -53.1
# mod:
#  0   -73.0
# Name: amount, dtype: float64
# var:
#  2205.016868027212
# ect:
#  46.95760713694014
# --------------------
# TELEPHONE BILL
# mean:
#  -12.045714285714283
# med:
#  -7.02
# mod:
#  0   -7.02
# 1   -6.38
# Name: amount, dtype: float64
# var:
#  105.01905306122445
# ect:
#  10.247880417980317
# --------------------
# GROCERIES
# mean:
#  -16.341282051282054
# med:
#  -12.24
# mod:
#  0    -60.16
# 1    -42.45
# 2    -42.42
# 3    -33.55
# 4    -32.67
# 5    -29.18
# 6    -28.11
# 7    -27.68
# 8    -26.58
# 9    -26.19
# 10   -23.43
# 11   -22.59
# 12   -21.73
# 13   -20.59
# 14   -18.45
# 15   -17.16
# 16   -13.59
# 17   -12.96
# 18   -12.49
# 19   -12.24
# 20   -10.91
# 21   -10.36
# 22    -9.88
# 23    -9.60
# 24    -9.31
# 25    -9.11
# 26    -6.89
# 27    -6.80
# 28    -6.60
# 29    -5.88
# 30    -4.63
# 31    -4.41
# 32    -4.39
# 33    -3.48
# 34    -2.93
# 35    -2.56
# 36    -2.51
# 37    -1.90
# 38    -0.94
# Name: amount, dtype: float64
# var:
#  177.0253547666009
# ect:
#  13.3050875520081
# --------------------
# BANK FEES
# mean:
#  -1.8857142857142857
# med:
#  -1.92
# mod:
#  0   -1.92
# Name: amount, dtype: float64
# var:
#  0.0015673469387755044
# ect:
#  0.03958973274443141
# --------------------
# RESTAURANT
# mean:
#  -10.3325
# med:
#  -10.1
# mod:
#  0   -9.2
# Name: amount, dtype: float64
# var:
#  2.8531937500000004
# ect:
#  1.689139943876765
# --------------------
# RENT
# mean:
#  -345.0
# med:
#  -345.0
# mod:
#  0   -345.0
# Name: amount, dtype: float64
# var:
#  0.0
# ect:
#  0.0

# %%
for cat in data["categ"].unique():
    subset = data[data.categ == cat] # Creation of sub-sample
    print("-"*20)
    print(cat)
    print("mean:\n",subset['amount'].mean())
    print("med:\n",subset['amount'].median())
    print("mod:\n",subset['amount'].mode())
    print("var:\n",subset['amount'].var(ddof=0))
    print("ect:\n",subset['amount'].std(ddof=0))
    print("skw:\n",subset['amount'].skew())
    print("kur:\n",subset['amount'].kurtosis())
    subset["amount"].hist() # Creates the histogram
    plt.show()  # Displays the histogram
    subset.boxplot(column="amount", vert=False)
    plt.show()
# Out:
# --------------------
# OTHER
# mean:
#  23.43320754716981
# med:
#  -8.31
# mod:
#  0   -1.6
# Name: amount, dtype: float64
# var:
#  40401.82999254183
# ect:
#  201.00206464746034
# skw:
#  3.1215325222336427
# kur:
#  12.716537970826296
# --------------------
# TRANSPORT
# mean:
#  -52.99714285714286
# med:
#  -53.1
# mod:
#  0   -73.0
# Name: amount, dtype: float64
# var:
#  2205.016868027212
# ect:
#  46.95760713694014
# skw:
#  -1.248265076217821
# kur:
#  2.1922705326917487
# --------------------
# TELEPHONE BILL
# mean:
#  -12.045714285714283
# med:
#  -7.02
# mod:
#  0   -7.02
# 1   -6.38
# Name: amount, dtype: float64
# var:
#  105.01905306122445
# ect:
#  10.247880417980317
# skw:
#  -2.3876514564281526
# kur:
#  5.798563367885492
# --------------------
# GROCERIES
# mean:
#  -16.341282051282054
# med:
#  -12.24
# mod:
#  0    -60.16
# 1    -42.45
# 2    -42.42
# 3    -33.55
# 4    -32.67
# 5    -29.18
# 6    -28.11
# 7    -27.68
# 8    -26.58
# 9    -26.19
# 10   -23.43
# 11   -22.59
# 12   -21.73
# 13   -20.59
# 14   -18.45
# 15   -17.16
# 16   -13.59
# 17   -12.96
# 18   -12.49
# 19   -12.24
# 20   -10.91
# 21   -10.36
# 22    -9.88
# 23    -9.60
# 24    -9.31
# 25    -9.11
# 26    -6.89
# 27    -6.80
# 28    -6.60
# 29    -5.88
# 30    -4.63
# 31    -4.41
# 32    -4.39
# 33    -3.48
# 34    -2.93
# 35    -2.56
# 36    -2.51
# 37    -1.90
# 38    -0.94
# Name: amount, dtype: float64
# var:
#  177.0253547666009
# ect:
#  13.3050875520081
# skw:
#  -1.246748830645698
# kur:
#  1.604730494087499
# --------------------
# BANK FEES
# mean:
#  -1.8857142857142857
# med:
#  -1.92
# mod:
#  0   -1.92
# Name: amount, dtype: float64
# var:
#  0.0015673469387755044
# ect:
#  0.03958973274443141
# skw:
#  0.37416573867739106
# kur:
#  -2.800000000000003
# --------------------
# RESTAURANT
# mean:
#  -10.3325
# med:
#  -10.1
# mod:
#  0   -9.2
# Name: amount, dtype: float64
# var:
#  2.8531937500000004
# ect:
#  1.689139943876765
# skw:
#  -0.8883503487158837
# kur:
#  0.5988855591691937
# --------------------
# RENT
# mean:
#  -345.0
# med:
#  -345.0
# mod:
#  0   -345.0
# Name: amount, dtype: float64
# var:
#  0.0
# ect:
#  0.0
# skw:
#  0.0
# kur:
#  0.0

# %% [markdown]
# What you will learn
# essential data visualization techniques and apply them using Matplotlib and Seaborn.
# why data visualization is crucial and how to create various types of plots, including line graphs, bar charts, and more. These skills will empower you to effectively communicate insights from data, a fundamental aspect of data analysis.
#
#
# What you will create :
# Visualizations for temperature variations, monthly sales data, product sales analysis, and favorite fruits distribution, enhancing your data visualization and analysis capabilities.
#
#
# 🌟 Exercise 1 : Understanding Data Visualization
# Instructions
# Explain why data visualization is important in data analysis.
# Describe the purpose of a line graph in data visualization.
#
#
# 🌟 Exercise 2 : Creating a Line Plot for Temperature Variation
# Instructions
# Create a simple line plot using Matplotlib that represents the temperature variations over a week.
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.
#
#
# 🌟 Exercise 3 : Visualizing Monthly Sales with a Bar Chart
# Instructions
# Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.
#
#
# 🌟 Exercise 4 : Data Visualisation
# Instructions
# Using the dataset: sales_data.csv
#
# Calculate the total quantity of products sold by the company.
# Identify the category that had the highest revenue and calculate how much revenue it generated.
# Determine the average revenue per sale in the dataset.
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).
#
#
# 🌟 Exercise 5 : Data Visualisation Using MatPlotLib
# Instructions
# Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.
# Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.
# Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %% [markdown]
#  🌟 Exercise 1 : Understanding Data Visualization
# Explain why data visualization is important in data analysis.
# -Data visualization is important as it helps to bring teh data to life and can help storytelling when it comes to conveying what daata is important and what is not. It also helps to understand where the standard deviation is and if anything in the data set needs to be adjusted.
#
# Describe the purpose of a line graph in data visualization.
# -Line Graphs are used extensively to show case changing trend of a certain variable over time or moving X-axis. A basic line plot can be created by plotting a list of values against another. Its recommended to avoid using Line Graphs when a variable is dependent on qualitative variable(X-axis). Here’s an example:

# %% [markdown]
# 🌟 Exercise 2 : Creating a Line Plot for Temperature Variation
# Instructions
# - Create a simple line plot using Matplotlib that represents the temperature variations over a week.
# - Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
import sklearn.datasets as datasets

temperatures = [72, 74, 76, 80, 82, 78, 75] 
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plt.plot(days, temperatures, marker='o')
plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.title('Temperature Variation Over a Week')
plt.grid(True)
plt.show()

# %% [markdown]
# 🌟 Exercise 3 : Visualizing Monthly Sales with a Bar Chart
# Instructions
# - Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
# - Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.

# %%
month = ["January", "February", "March", "April", "May"]
sales = [5000, 5500, 6200, 7000, 7500]
plt.bar(month, sales)
plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")
plt.title("Monthly Sales")
plt.show()

# %% [markdown]
# 🌟 Exercise 4 : Data Visualisation
# Instructions
# Using the dataset: sales_data.csv
#
# - Calculate the total quantity of products sold by the company.
# - Identify the category that had the highest revenue and calculate how much revenue it generated.
# - Determine the average revenue per sale in the dataset.
# - Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
df = pd.read_csv('/Users/teitelbaumsair/Desktop/DI_Bootcamp/W5/D1/EXERCISE XP/sales_data.csv')
df.columns
# Out:
# Index(['date', 'product', 'category', 'price', 'quantity', 'revenue'], dtype='object')

# %%
df.isna().sum()
#fill the missing values of price, quantity, and revenue with mean
df['price'] = df['price'].fillna(df['price'].mean())
df['quantity'] = df['quantity'].fillna(df['quantity'].mean())
df['revenue'] = df['revenue'].fillna(df['revenue'].mean())

df.isna().sum()
# Out:
# date        0
# product     0
# category    0
# price       0
# quantity    0
# revenue     0
# dtype: int64

# %%
df.duplicated().sum()
df.loc[df.duplicated(), :]
df.drop_duplicates(inplace=True)

# %%
# Calculate the total quantity of products sold by the company.
total_quantity = df['quantity'].sum()
print(total_quantity)
# Out:
# 5330.0

# %%
# Identify the category that had the highest revenue and calculate how much revenue it generated.
df['category'].value_counts()
category_sums = df.groupby('category')[['price', 'quantity']].sum().sort_values(by='price', ascending=False)
print(category_sums)
# Out:
#                price  quantity
# category
# Electronics  57300.0    1439.0
# Accessories  10680.0     962.0
# Clothing      6340.0    2221.0
# Shoes         1840.0     258.0
# Bags          1150.0     390.0
# Shoeses         80.0      12.0
# Bgas            50.0      18.0
# Clohting        40.0      30.0

# %% [markdown]
# 🌟 Exercise 5 : Data Visualisation Using MatPlotLib
# Instructions
# - Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.
# - Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.
# - Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-11, 12)  # Include 11 as endpoint
y = x**2

# Create the plot
plt.figure(figsize=(8, 5))

plt.plot(x, y, marker='o', color='red', linestyle='-', label='y = x^2', zorder=2)

# Add title, labels, grid, and legend
plt.title('Line Plot with Scatter Points for y = x^2', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

plt.show()

# %%
products = ['A', 'B', 'C', 'D']
sales = [15, 30, 45, 20]

plt.bar(products, sales)
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Weekly Sales Data')
plt.show()

# %%
# - Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.
fruits = ["Apples", "Bananas", "Cherries", "Dates"]
percentages = [40, 30, 20, 10]
colors = ["green", "yellow", "red", "brown"]

plt.pie(percentages, labels=fruits, colors=colors, autopct="%1.1f%%")
plt.legend()
plt.show()

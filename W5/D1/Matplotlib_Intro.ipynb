# %% [markdown]
# In Matplotlib, a plot is contained within a Figure object. This Figure can contain one or more Axes objects, each of which is an individual plot with its own x-axis, y-axis, labels, etc.
#
# Figure: Think of the Figure as the overall window or page where your plot (or plots) will appear. You can create multiple independent figures.
# Axes: These are what we often think of as ‘plots’. A single figure can contain multiple Axes.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()  # Create a figure containing a single axes.

# %% [markdown]
# This command creates a Figure object (fig) and a single Axes object (ax).
#
# Creating a basic plot in Matplotlib involves defining the x and y data points and using a plot function, like plt.plot() for line plots or plt.bar() for bar charts.

# %%
# Sample data - line plot
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
#y = f(x)
# Create a new figure
plt.figure()

# Plot x and y
plt.plot(x, y)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data - line plot
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

# Create a new figure
plt.figure()

plt.xlabel('x-axis')  # Correct method name
plt.ylabel('y-axis')  # Correct method name
plt.title('Sample Data')  

# Plot x and y with colors and indicators
plt.plot(x, y, color='green', linestyle='dashed', linewidth=3, 
         marker='o', markerfacecolor='blue', markersize=12)

# Show the plot
plt.show()

# %%
#PRACTICE Q:
#Create a line plot for the function y = x^2 for x ranging from 0 to 10. x = 0, 1, 2...10 y = 0, 1, 4, .... 100

# import matplotlib.pyplot as plt

# # Generate x values using a range
# x = list(range(0, 11))
# y = [i**2 for i in x]

# # Create the plot
# plt.plot(x, y, marker="o", markersize=10, color="blue", linestyle = "--", linewidth = 2)
# plt.xlabel("x")
# plt.ylabel("y")
# plt.title("My Line Plot")
# # Display the plot
# plt.show()


#INSTRUCTORS SOLUTION:
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 11)
y = x**2

plt.figure()

#scatter plot
plt.scatter(x, y, marker="o", color="blue")

#line through scatter plot
plt.plot(x, y, color="red", linestyle="-", linewidth=2, marker = 'o', label = "scatter points", zorder=1)

#add title, grid, legend
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend()
plt.title("Teacher Line Plot")
# Out:
# Text(0.5, 1.0, 'Teacher Line Plot')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define x values and the two functions
x = np.arange(0, 11)
y1 = x**2
y2 = x**4

# Create the figure and the first axis
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the first function on the first axis
ax.plot(x, y1, marker='o', color='blue', label='y=x^2')
ax.set_xlabel('x')  # Label for the x-axis
ax.set_ylabel('y (blue)', color='blue')  # Label for the y-axis
ax.grid(True, linestyle='--', alpha=0.7)  # Add grid lines
ax.legend(loc='upper left')  # Add legend for the first function

# Create a second y-axis sharing the same x-axis
ax2 = ax.twinx()
ax2.plot(x, y2, marker='o', color='red', label='y=x^4')
ax2.scatter(x[2], y2[2], color='green', marker='X', s=50, zorder=5)  # Add X marker
ax2.text(x[2], y2[2], 'Important', color='green', fontsize=12)  # Add annotation
ax2.set_ylabel('y (red)', color='red')  # Label for the second y-axis
ax2.legend(loc='upper center')  # Add legend for the second function

# Add a title to the figure
fig.suptitle('Comparison y=x^2 and y=x^4', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# BAR CHARTS:
#
# Vertical Bar Chart
# - Vertical bar charts are the standard type of bar chart and are useful for comparing data across different categories.
#
# Horizontal Bar Chart
# - Horizontal bar charts are particularly useful when dealing with long category names or when you have a large number of categories.
#
# Adding Error Bars for Data Variability Representation
# - Error bars can be added to bar charts to indicate the variability of the data and to give a clearer picture of the precision in the measurements.

# %%
# Sample data
categories = ['Category A', 'Category B', 'Category C']
values = [3, 7, 2]

# Create a bar chart
plt.bar(categories, values)

# Show the plot
plt.show()

# %% [markdown]
# Line Graphs are used extensively to show case changing trend of a certain variable over time or moving X-axis. A basic line plot can be created by plotting a list of values against another. Its recommended to avoid using Line Graphs when a variable is dependent on qualitative variable(X-axis). Here’s an example:

# %%
#VERTICAL BAR
import matplotlib.pyplot as plt

categories = ['Apples', 'Bananas', 'Oranges', 'Grapes']
values = [20, 35, 30, 15]

plt.bar(categories, values)
plt.title('Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %%
#HORIZONTAL BAR

plt.barh(categories, values)
plt.title('Fruit Sales Data')
plt.xlabel('Sales')
plt.ylabel('Fruit')
plt.show()

# %% [markdown]
# HISTOGRAMS
#
# This code generates a histogram of a dataset that follows a normal distribution. The bins parameter determines the number of bins used. Histograms can also be used to compare different datasets. By overlaying multiple histograms, you can visualize how different distributions compare with each other.

# %%
#Histograms

#This code generates a histogram of a dataset that follows a normal distribution. The bins parameter determines the number of bins used.

import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.normal(0, 1, 1000)

# Create a histogram
plt.hist(data, bins=30, edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# Customizing Bin Sizes and Colors
# Different bin sizes and colors
plt.hist(data, bins=15, color='skyblue', edgecolor='black')
plt.title("Customized Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# Additional data for comparison
data2 = np.random.normal(5, 1.5, 1000)

# Create overlapping histograms
plt.hist(data, bins=30, alpha=0.5, label='Dataset 1', edgecolor='black')
plt.hist(data2, bins=30, alpha=0.5, label='Dataset 2', color='orange', edgecolor='black')
plt.title("Comparing Two Distributions")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()

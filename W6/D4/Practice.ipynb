# %% [markdown]
# ### **Scenario: Bakery Analysis**
#
# A bakery wants to analyze customer purchases and ingredient variability. Here’s the breakdown:
#
# 1. **PMF**: The bakery sells different types of pastries: croissants, muffins, and scones. You want to calculate the probability of selling each type based on past data.
# 2. **PDF**: The weight of a croissant is normally distributed. You want to calculate the probability of a croissant weighing within a specific range.
# 3. **Gaussian Distribution**: Use the normal distribution to understand how consistent the croissant weights are.
# 4. **Binomial Distribution**: On average, 80% of customers buy croissants. Out of 10 customers, what’s the probability that exactly 8 of them buy croissants?
#
# ---
#
# ### **Given Data**:
#
# 1. **PMF Data**:
#    - Croissants: Sold 40 times.
#    - Muffins: Sold 35 times.
#    - Scones: Sold 25 times.
#    - Total: 100 sales.
#
# 2. **PDF Data**:
#    - Average weight of a croissant: \( \mu = 60 \) grams.
#    - Standard deviation: \( \sigma = 5 \) grams.
#
# 3. **Binomial Distribution**:
#    - Probability of buying a croissant (\( p \)): 0.8.
#    - Number of customers (\( n \)): 10.
#
# ---
#
# ### **Questions**:
#
# 1. What is the probability of selling each type of pastry (PMF)?
# 2. What is the probability that a randomly chosen croissant weighs between 58 and 62 grams (PDF)?
# 3. What is the probability that exactly 8 out of 10 customers buy croissants (Binomial)?

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy as sp

pmf_data = {
    'Croissants': 40,
    'Scones': 35,
    'Muffins': 25
}

plt.figure(figsize=(10, 6))
plt.bar(pmf_data.keys(), pmf_data.values(), color='skyblue')
plt.title('Probability Mass Function (PMF) of Food Items')
plt.xlabel('Food Items')
plt.ylabel('Items Sold')
plt.show()

# %%
# 2. What is the probability that a randomly chosen croissant weighs between 58 and 62 grams (PDF)?
#    Average weight of a croissant: \( \mu = 60 \) grams.
#    Standard deviation: \( \sigma = 5 \) grams.

from scipy import stats
import numpy as np
from scipy.stats import norm
mu = 60
sigma = 5

# Calculate the probability using the cumulative distribution function (CDF)
probability = stats.norm.cdf(62, mu, sigma) - stats.norm.cdf(58, mu, sigma)

print(f"Probability that a randomly chosen croissant weighs between 58 and 62 grams: {(probability*100).round(2)}%")

plt.figure(figsize=(10, 6))
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
pdf = norm.pdf(x, loc=mu, scale=sigma)
plt.plot(x, pdf, label='PDF', color='red')
plt.fill_between(x, pdf, where=(x >= 58) & (x <= 62), alpha=0.3, color='blue', label='Probability')
plt.title('Probability Distribution of Croissant Weights')
plt.xlabel('Weight (grams)')
plt.ylabel('Probability Density')
plt.legend(fontsize=12)
plt.grid(True)
plt.show()
# Out:
# Probability that a randomly chosen croissant weighs between 58 and 62 grams: 31.08%

# %%
# 3. What is the probability that exactly 8 out of 10 customers buy croissants (Binomial)?
# - Probability of buying a croissant (\( p \)): 0.8.
# - Number of customers (\( n \)): 10.
from scipy.stats import binom 
import matplotlib.pyplot as plt

n_customers, p_croissant = 10, 0.8  # Number of trials and success probability
k = 8  # Exact number of successes
prob_binomial = binom.pmf(k, n=n_customers, p=p_croissant)
print(f"\nProbability of exactly 8 out of 10 customers buying croissants: {prob_binomial:.2f}")

# Visualization of Binomial Distribution
x_binom = range(0, n_customers + 1)
binomial_pmf = binom.pmf(x_binom, n=n_customers, p=p_croissant)
plt.figure(figsize=(8, 5))
plt.bar(x_binom, binomial_pmf, color='purple', alpha=0.7)
plt.title("Binomial PMF: Customer Croissant Purchases", fontsize=16)
plt.xlabel("Number of Customers Buying Croissants", fontsize=14)
plt.ylabel("Probability", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# Probability of exactly 8 out of 10 customers buying croissants: 0.30

# %% [markdown]
# Background:
#
# You are given a subset of data from a market study aimed at understanding consumer behavior. The dataset includes variables such as age, monthly income, online purchase frequency, and hours spent on social media.
#
# Dataset Sample:
#
# The first five rows of the dataset are as follows:
#
#
# Age	Monthly Income	Online Purchase Frequency	Hours Spent on Social Media
# 25	    3200	            15	                        30
# 40	    5800	            8	                          15
# 30	    4500	            12	                        25
# 22	    2800	            18	                        40
# 35	    500	              10	                        20
#
#
# Statistical Measure	Value
# Pearson Correlation Coefficient	    0.75
# Spearman Rank Correlation	       -0.60
# Covariance between Age and Income	1500
#
# Tasks:
#
# 1. Interpret the Pearson Correlation Coefficient:
#
# Explain what a coefficient of 0.75 suggests about the relationship between Monthly Income and Online Purchase Frequency.
# Discuss potential reasons behind this correlation based on the sample data.
# - **Explanation:**
#   A Pearson correlation coefficient of **0.75** indicates a **strong positive linear relationship** between **Monthly Income** and **Online Purchase Frequency**. This suggests that as Monthly Income increases, the frequency of online purchases also tends to increase. However, it is not a perfect correlation (+1), meaning other factors may also influence purchase frequency.
#
# - **Potential Reasons:**
#   - Individuals with higher income might have greater disposable income, enabling them to spend more on online purchases.
#   - Lower-income individuals may prioritize necessities, limiting their online purchase frequency.
#   - The availability of online shopping platforms targeting higher-income demographics could also play a role.
#
#
# 2. Analyze the Spearman Rank Correlation:
# Describe what the -0.60 correlation signifies about the relationship between Age and Hours Spent on Social Media.
# Propose hypotheses that could explain this negative correlation with reference to the dataset.
# - **Explanation:**
#   A Spearman rank correlation of **-0.60** indicates a **moderate-to-strong negative monotonic relationship** between **Age** and **Hours Spent on Social Media**. This means that as Age increases, the number of hours spent on social media generally decreases, though not perfectly.
#
# - **Hypotheses:**
#   - **Younger individuals** (e.g., those in their 20s) may use social media more frequently for entertainment, networking, or staying updated with trends.
#   - **Older individuals** (e.g., those in their 30s or 40s) might have less time for social media due to professional and familial commitments.
#   - Generational differences in familiarity with social media platforms could also explain this trend, with younger individuals being more accustomed to these tools.
#
#
# 3. Discuss the Covariance Finding:
# Interpret the positive covariance of 1500 between Age and Monthly Income.
# Relate this covariance to the sample data and suggest real-world scenarios that it might reflect.
# - **Interpretation:**
#   A positive covariance of **1500** between **Age** and **Monthly Income** indicates that these variables tend to increase together. Older individuals in the sample are generally associated with higher income levels.
#
# - **Relation to Sample Data:**
#   - The data shows that **older individuals** (e.g., 40 and 35) have **higher monthly incomes** (e.g., 5800 and 5000) compared to **younger individuals** (e.g., 22 and 25) with **lower incomes** (e.g., 2800 and 3200).
#
# - **Real-World Scenarios:**
#   - **Age** often correlates with **career progression** and **work experience**, leading to higher earning potential over time.
#   - **Younger individuals** may still be in educational or entry-level positions, contributing to lower income levels.
#
#
# 4. Correlation vs. Causation:
# Reflect on the provided statistics and discuss why it is important to not confuse correlation with causation in market studies.
# - **Explanation:**
#   - **Correlation** measures the degree of association between two variables but does not imply that one causes the other. For example, the correlation between **Monthly Income** and **Online Purchase Frequency** does not mean higher income directly causes more purchases—other factors like marketing strategies, personal preferences, or external economic conditions could also be at play.
#
# - **Importance in Market Studies:**
#   - Misinterpreting **correlation** as **causation** can lead to flawed strategies, such as targeting only high-income individuals for online sales campaigns without considering other drivers like internet accessibility or promotional offers.
#   - Rigorous studies (e.g., experiments or causal inference methods) are needed to establish causal relationships and ensure actionable insights.
